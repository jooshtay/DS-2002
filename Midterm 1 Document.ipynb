# %% [markdown]
# # Midterm Project 1

# %% [markdown]
# ## 1.0 Creating an ETL process from a local file containing retail sales data

# %% [markdown]
# Steps:

# %% [markdown]
# 1.1 Create a new database called 'Sales' & import the original fact table (data)

# %% [markdown]
# 1.2 Create dimension tables

# %% [markdown]
# 1.3 Populate those dimension tables

# %% [markdown]
# 1.4 Validate that the data

# %% [markdown]
# 1.5 Create a new fact table using MySQL

# %% [markdown]
# 1.6 Using Python to query in MySQL

# %% [markdown]
# ## 1.1 Creating a new database and importing data

# %% [markdown]
# I created a new schema, 'Sales' & imported a csv file containing that retail sales data into this database. The subsequent steps work towards creating a new fact table.

# %% [markdown]
# ## 1.2 Creating dimension tables

# %% [markdown]
# <div>
# <img src = "attachment:Screen%20Shot%202022-12-14%20at%202.04.43%20AM.png" width="300" height = "200" >
# </div>

# %% [markdown]
# ## 1.3 Populating the dimension tables

# %% [markdown]
# <div>
# <img src = "attachment:Screen%20Shot%202022-12-14%20at%202.22.28%20AM.png" width="300" height = "200" >
#
# </div>

# %% [markdown]
# <div>
# <img src = "attachment:Screen%20Shot%202022-12-14%20at%202.22.34%20AM.png" width="300" height = "200" >
# </div>

# %% [markdown]
# <div>
# <img src = "attachment:Screen%20Shot%202022-12-14%20at%202.22.40%20AM.png" width="300" height = "200" >
# </div>

# %% [markdown]
# ## 1.4 Validating the data

# %% [markdown]
# <div>
# <img src = "attachment:Screen%20Shot%202022-12-14%20at%202.33.37%20AM.png" width="400" height = "260" >
# </div>

# %% [markdown]
# ## 1.5 Creating a new fact table

# %% [markdown]
# <div>
# <img src = "attachment:Screen%20Shot%202022-12-14%20at%202.39.07%20AM.png" width="500" height = 300" >
# </div>

# %% [markdown]
# Since I'm join 3 tables together to make one fact table, I begin by joining 2 tables together. I name the first table created 'fact_table_intermediary'.

# %% [markdown]
# <div>
# <img src = "attachment:Screen%20Shot%202022-12-14%20at%202.42.32%20AM.png" width="600" height = "400" >
# </div>

# %% [markdown]
# The final table created is called 'new_fact_table'.

# %% [markdown]
# ## 1.6 Using Python to run queries in MySQL

# %%
import os
import datetime
import pymongo
import pprint
import pandas as pd
import pymysql
import mysql.connector
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import datetime

# %%
#Connecting Python to MySQL

host_name = "localhost"
host_ip = "127.0.0.1"
port = "3306"

user_id = "jooshtay"
pwd = ""
db_name = "Sales"

# %%
# Selecting the most expensive product

conn = pymysql.connect( host = host_name , user = user_id , password = pwd , database = db_name )

most_exp = pd.read_sql( "SELECT Product, Price_Each FROM new_fact_table WHERE Price_Each = ( SELECT MAX( Price_Each ) FROM new_fact_table);" , conn)
conn.close()
most_exp.head( 1 )

# %% [markdown]
# <div>
# <img src = "attachment:Screen%20Shot%202022-12-14%20at%202.54.03%20AM.png" width="300" height = "200" >
# </div>

# %%
# Selecting the least expensive product
conn = pymysql.connect( host=host_name , user=user_id , password=pwd , database=db_name )

least_exp = pd.read_sql( "SELECT Product, Price_Each FROM new_fact_table WHERE Price_Each = ( SELECT MIN( Price_Each ) FROM new_fact_table);" , conn)
conn.close()
least_exp.head( 1 )

# %% [markdown]
# <div>
# <img src = "attachment:Screen%20Shot%202022-12-14%20at%203.02.35%20AM.png" width="300" height = "200" >
# </div>

# %%
# Finding products that cost more than the average price 
conn = pymysql.connect( host=host_name , user=user_id , password=pwd , database=db_name )

avg_price = pd.read_sql( "SELECT Product, Price_Each FROM new_fact_table WHERE Price_Each > ( SELECT AVG( Price_Each ) FROM new_fact_table);" , conn)
conn.close()
avg_price.head( )

# %% [markdown]
# <div>
# <img src = "attachment:Screen%20Shot%202022-12-14%20at%203.05.32%20AM.png" width="300" height = "200" >
# </div>

# %% [markdown]
# ## 2.0 Querying MongoDB using Python

# %% [markdown]
# <div>
# <img src = "attachment:Screen%20Shot%202022-12-14%20at%203.09.27%20AM.png" width="550" height = "450" >
# </div>
